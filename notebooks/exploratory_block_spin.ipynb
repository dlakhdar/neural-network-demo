# %%
import numpy as np 

n = 10
N = n**2
spins = np.random.choice(a=[-1,1],size=(N,N))
l = 5
d = 2
N_per_block = (N)/l**d
n_blocks = int(np.sqrt(N_per_block))
block_spins = np.zeros((n_blocks,n_blocks))

r,s = block_spins.shape

# for i in  range(0,r):
#     for j in range(0,s):
#         block_spins[i,j] = spins

# %%
# Out:
# np.float64(0.3356135116133815)
